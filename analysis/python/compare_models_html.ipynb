# %%
import numpy as np
import subprocess
from IPython.display import Image, display_png

# %% [markdown]
# # Model light curves taken mean over all the angle

# %% [markdown]
# ## 0.2 Msun He WD

# %%
display_png(Image("figs/hewd/lc_mean.png"))

# %% [markdown]
# ## 0.4 Msun He WD

# %%
display_png(Image("figs/he04/lc_mean.png"))

# %% [markdown]
# ## 0.6 Msun CO WD

# %%
display_png(Image("figs/cowd/lc_mean.png"))

# %% [markdown]
# ## All models

# %%
display_png(Image("figs/lc_mean_all.png"))

# %% [markdown]
# ## Phillips relation

# %%
display_png(Image("figs/Phillips_relation2.png"))

# %% [markdown]
# ### Superpose on figure in reference Jha (2017): review of SNe Iax

# %%
display_png(Image("figs/Phillips_relation_on_reference.png"))

# %% [markdown]
# ## time to decrease from peak by 1 mag v.s. peak bolometric luminosity

# %%
display_png(Image("figs/time_luminosity2.png"))

# %% [markdown]
# ### Superpose on figure in reference Garcia-Berro (2017)

# %%
display_png(Image("figs/time_luminosity_on_reference.png"))
